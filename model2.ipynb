# %% [markdown]
# # **Dataset dan Konfigurasi Sistem**

# %% [markdown]
# Instal pustaka splitfolder

# %%
# !pip install split-folders -qq

# %% [markdown]
# Impor pustaka untuk kebutuhan visualisasi data dan pembangunan model

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import splitfolders
import matplotlib.pyplot as plt

# %% [markdown]
# Atur random seed untuk memastikan reproduktivitas hasil

# %%
tf.random.set_seed(42)

# %% [markdown]
# Deklarasi variabel global untuk ukuran citra

# %%
IMAGE_SIZE = (224, 224)

# %% [markdown]
# # **Perancangan Data**

# %% [markdown]
# Bagi dataset dengan rasio 80:10:10

# %%
splitfolders.ratio('/kaggle/input/posisi-duduk-ergonomis/sitting-posture-dataset', ratio=(0.8, 0.1, 0.1))
# Out:
# Copying files: 1620 files [01:17, 20.90 files/s]

# %% [markdown]
# Muat dataset dengan parameter yang telah ditentukan

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    'output/train',
    label_mode='binary',
    batch_size=32,
    image_size=IMAGE_SIZE,
    interpolation='bilinear',
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    'output/val',
    label_mode='binary',
    batch_size=32,
    image_size=IMAGE_SIZE,
    interpolation='bilinear',
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    'output/test',
    label_mode='binary',
    batch_size=32,
    image_size=IMAGE_SIZE,
    interpolation='bilinear',
    shuffle=False,
)
# Out:
# Found 1296 files belonging to 2 classes.
# Found 162 files belonging to 2 classes.
# Found 162 files belonging to 2 classes.

# %% [markdown]
# Ambil batch pertama dari data train untuk kebutuhan demonstrasi

# %%
images, labels = next(iter(train_ds.take(1)))

# %% [markdown]
# Tampilkan 5 sampel data train pertama dari batch pertama

# %%
for i in range(min(5, images.shape[0])):
  plt.imshow(images[i].numpy().astype("uint8"))
  label_text = "Ergonomis" if labels[i].numpy() == 0 else "Tidak Ergonomis"
  plt.title(f"Kelas: {label_text}")
  plt.show()

# %% [markdown]
# Optimasi dataset dengan autotune untuk mempercepat pelatihan data

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # **Pembuatan Model**

# %% [markdown]
# Deklarasi Augmentasi Data

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomZoom((-0.2, 0.0)),
    layers.RandomBrightness((-0.2, 0.0)),
], name='augmentation')

# %% [markdown]
# Deklarasi model dengan arsitektur MobileNetV2

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(*IMAGE_SIZE, 3),
    include_top=False,
    weights='imagenet',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Susun layer untuk model dan bekukan bobot agar tidak diperbarui saat pelatihan model

# %%
base_model.trainable = False

inputs = tf.keras.Input(shape=(*IMAGE_SIZE,3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Instal graphviz dan pydot untuk visualisasi model

# %%
# !pip install pydot graphviz
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (3.0.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.2.0)

# %% [markdown]
# Tampilkan layer model

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=True,
    show_layer_names=True,
    show_layer_activations=True,
    dpi=100
)

# %% [markdown]
# Tampilkan hasil augmentasi data dari sampel pertama

# %%
print("Original Image shape\t: ", images[0].shape)
print("Augmented Image shape\t: ", data_augmentation(tf.expand_dims(images[0], axis=0))[0].shape)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(images[0].numpy().astype("uint8"))
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(data_augmentation(tf.expand_dims(images[0], axis=0)).numpy()[0].astype("uint8"))
plt.title("Augmented Image")
plt.show()
# Out:
# Original Image shape	:  (224, 224, 3)
# Augmented Image shape	:  (224, 224, 3)

# %% [markdown]
# Tampilkan nilai piksel sampel pertama dari batch pertama sebelum dan setelah dilakukan penskalaan dan pemusatan data

# %%
print("Nilai piksel sebelum penskalaan dan pemusatan data:")
print(images[0].numpy().astype("uint8"))

print("\nNilai piksel setelah penskalaan dan pemusatan data:")
print(preprocess_input(tf.expand_dims(images[0], axis=0)).numpy()[0])
# Out:
# Nilai piksel sebelum penskalaan dan pemusatan data:
# [[[182 192 188]
#   [188 194 194]
#   [188 196 197]
#   ...
#   [187 189 188]
#   [185 187 186]
#   [185 186 186]]
#
#  [[187 193 193]
#   [185 194 193]
#   [185 195 194]
#   ...
#   [186 187 187]
#   [182 185 184]
#   [183 185 184]]
#
#  [[185 195 192]
#   [188 194 192]
#   [185 195 196]
#   ...
#   [185 184 185]
#   [186 184 185]
#   [186 186 186]]
#
#  ...
#
#  [[ 50   0   0]
#   [108  69  64]
#   [111  98  87]
#   ...
#   [113  64  31]
#   [110  64  31]
#   [109  70  33]]
#
#  [[ 57  12   8]
#   [100  76  66]
#   [131 121 112]
#   ...
#   [116  65  31]
#   [118  62  32]
#   [115  69  34]]
#
#  [[ 13   4   2]
#   [ 92  70  61]
#   [143 133 128]
#   ...
#   [121  67  28]
#   [128  70  33]
#   [120  72  34]]]
#
# Nilai piksel setelah penskalaan dan pemusatan data:
# [[[ 0.4302522   0.5093237   0.48155272]
#   [ 0.47803116  0.52509     0.52509   ]
#   [ 0.47891152  0.5444578   0.55174065]
#   ...
#   [ 0.46826684  0.48395312  0.47610998]
#   [ 0.4557029   0.47138917  0.46354604]
#   [ 0.4512204   0.46330488  0.4662671 ]]
#
#  [[ 0.4683473   0.51540613  0.51540613]
#   [ 0.45146048  0.5220487   0.5142056 ]
#   [ 0.4515406   0.52997196  0.52324927]
#   ...
#   [ 0.46634662  0.46746707  0.4669069 ]
#   [ 0.4284916   0.4587437   0.45090055]
#   [ 0.4421773   0.45786357  0.45002043]]
#
#  [[ 0.45666265  0.5317327   0.5059624 ]
#   [ 0.48035204  0.52741086  0.5117246 ]
#   [ 0.45714283  0.5299721   0.5406163 ]
#   ...
#   [ 0.458104    0.4457791   0.4519416 ]
#   [ 0.46554184  0.44985557  0.4576987 ]
#   [ 0.46010375  0.46106386  0.4605838 ]]
#
#  ...
#
#  [[-0.60392296 -0.9995202  -1.        ]
#   [-0.14797688 -0.45738137 -0.49747765]
#   [-0.12661201 -0.22408825 -0.3165266 ]
#   ...
#   [-0.11164016 -0.49763322 -0.75645673]
#   [-0.13365304 -0.49443734 -0.75326085]
#   [-0.13878214 -0.44873923 -0.7333363 ]]
#
#  [[-0.5518943  -0.8981962  -0.93020666]
#   [-0.21000063 -0.39879698 -0.47554517]
#   [ 0.02801037 -0.04786116 -0.11564416]
#   ...
#   [-0.08907014 -0.48291016 -0.7557368 ]
#   [-0.06722772 -0.5131644  -0.7490196 ]
#   [-0.09275311 -0.45761734 -0.7310891 ]]
#
#  [[-0.8979626  -0.9664675  -0.9792739 ]
#   [-0.27170432 -0.4492932  -0.5204482 ]
#   [ 0.12244177  0.04673707  0.00520837]
#   ...
#   [-0.04953068 -0.46858704 -0.7739026 ]
#   [ 0.00512612 -0.44530278 -0.7354989 ]
#   [-0.0580228  -0.43417966 -0.7276509 ]]]

# %% [markdown]
# Tampilkan 20 feature map pertama dari sampel pertama

# %%
layer_name = 'out_relu'
feature_extractor = tf.keras.Model(inputs=base_model.input, outputs=base_model.get_layer(layer_name).output)
feature_maps = feature_extractor(tf.expand_dims(images[0], axis=0))

plt.figure(figsize=(10, 10))
for i in range(20):
  plt.subplot(4, 5, i + 1)
  plt.imshow(feature_maps[0, :, :, i], cmap='gray')
  plt.axis('off')

plt.show()

# %% [markdown]
# # **Pelatihan Model**

# %% [markdown]
# Deklarasi early stopping untuk mencegah overfitting selama pelatihan model

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %% [markdown]
# Bersihkan sesi Keras untuk membebaskan sumber daya

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# Kompilasi, latih, serta validasi model dengan data train dan data validation

# %%
model.compile(optimizer='rmsprop',
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

trained_model = model.fit(train_ds, validation_data=val_ds, epochs=100, callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.5848 - loss: 1.1367 - val_accuracy: 0.6420 - val_loss: 0.5929
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.7735 - loss: 0.4992 - val_accuracy: 0.8580 - val_loss: 0.3562
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.7941 - loss: 0.4430 - val_accuracy: 0.7160 - val_loss: 0.4884
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.8113 - loss: 0.4012 - val_accuracy: 0.8765 - val_loss: 0.2839
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8363 - loss: 0.4106 - val_accuracy: 0.8333 - val_loss: 0.3240
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8486 - loss: 0.3241 - val_accuracy: 0.8210 - val_loss: 0.3336
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8575 - loss: 0.3297 - val_accuracy: 0.9074 - val_loss: 0.2360
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8652 - loss: 0.3127 - val_accuracy: 0.8889 - val_loss: 0.2292
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8861 - loss: 0.2694 - val_accuracy: 0.8642 - val_loss: 0.2638
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.8835 - loss: 0.2887 - val_accuracy: 0.7160 - val_loss: 0.6281
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.8841 - loss: 0.2974 - val_accuracy: 0.8765 - val_loss: 0.2302
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8841 - loss: 0.2592 - val_accuracy: 0.9259 - val_loss: 0.1995
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.8822 - loss: 0.2625 - val_accuracy: 0.9383 - val_loss: 0.1745
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9062 - loss: 0.2317 - val_accuracy: 0.8272 - val_loss: 0.3335
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9017 - loss: 0.2250 - val_accuracy: 0.8704 - val_loss: 0.2696
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9116 - loss: 0.2029 - val_accuracy: 0.9198 - val_loss: 0.1717
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9170 - loss: 0.1992 - val_accuracy: 0.9074 - val_loss: 0.2012
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9248 - loss: 0.1887 - val_accuracy: 0.9074 - val_loss: 0.1953
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9467 - loss: 0.1577 - val_accuracy: 0.8827 - val_loss: 0.2216
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9501 - loss: 0.1337 - val_accuracy: 0.9321 - val_loss: 0.1793
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9360 - loss: 0.1730 - val_accuracy: 0.9136 - val_loss: 0.2002
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9353 - loss: 0.1551 - val_accuracy: 0.9012 - val_loss: 0.1848
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9506 - loss: 0.1451 - val_accuracy: 0.9321 - val_loss: 0.1918
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9468 - loss: 0.1427 - val_accuracy: 0.8704 - val_loss: 0.3006
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9452 - loss: 0.1379 - val_accuracy: 0.9506 - val_loss: 0.1410
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9486 - loss: 0.1392 - val_accuracy: 0.8210 - val_loss: 0.3601
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9465 - loss: 0.1361 - val_accuracy: 0.9383 - val_loss: 0.1527
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9366 - loss: 0.1655 - val_accuracy: 0.9383 - val_loss: 0.1618
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9594 - loss: 0.1198 - val_accuracy: 0.8457 - val_loss: 0.3525
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9578 - loss: 0.1148 - val_accuracy: 0.8827 - val_loss: 0.2762
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9376 - loss: 0.1408 - val_accuracy: 0.8642 - val_loss: 0.3234
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9511 - loss: 0.1128 - val_accuracy: 0.9259 - val_loss: 0.2046
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9325 - loss: 0.1642 - val_accuracy: 0.9568 - val_loss: 0.1410
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9565 - loss: 0.1229 - val_accuracy: 0.9259 - val_loss: 0.2232
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9443 - loss: 0.1422 - val_accuracy: 0.9136 - val_loss: 0.1581

# %% [markdown]
# Tampilkan Grafik Akurasi dan Loss Hasil Pelatihan Model

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(trained_model.history['accuracy'], label='Training Accuracy')
plt.plot(trained_model.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(trained_model.history['loss'], label='Training Loss')
plt.plot(trained_model.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Simpan model

# %%
model.save('model.keras')

# %% [markdown]
# # **Evaluasi Model**

# %% [markdown]
# Instal pustaka python-docx untuk kebutuhan penyimpanan hasil prediksi

# %%
pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Impor pustaka untuk kebutuhan evaluasi model dan penyimpanan hasil prediksi

# %%
import seaborn as sns
from sklearn import metrics
import os
import csv
import pandas as pd
from docx import Document
from docx.shared import Inches

# %% [markdown]
# Muat model yang telah disimpan

# %%
model = tf.keras.models.load_model('model.keras')

# %% [markdown]
# Ambil kelas aktual dari data test ke dalam list

# %%
actual = []
for images, labels in test_ds:
  for label in labels:
    actual.append(label.numpy())

# %% [markdown]
# Buat prediksi terhadap data test

# %%
predictions = model.predict(test_ds)
predicted = [1 if prediction > 0.5 else 0 for prediction in predictions]

accuracy = metrics.accuracy_score(actual, predicted)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# Test Accuracy: 95.06%

# %% [markdown]
# Simpan hasil prediksi ke dalam file berformat csv

# %%
# Get the total number of images in the test dataset
total_images = len(actual)

# Get a list of image file paths from the test dataset directory
image_paths = []
for filename in os.listdir('output/test/ergonomis'):
  image_paths.append(os.path.join('output/test/ergonomis', filename))
for filename in os.listdir('output/test/non-ergonomis'):
  image_paths.append(os.path.join('output/test/non-ergonomis', filename))

# Prepare a list to store actual labels, mapped from your `actual` variable
actual_labels = ['Ergonomis' if label == 0 else 'Tidak Ergonomis' for label in actual[:total_images]]

# Prepare a list to store predicted labels, mapped from your `predicted` variable
predicted_labels = ['Ergonomis' if label == 0 else 'Tidak Ergonomis' for label in predicted[:total_images]]

# Create and write to the CSV file
with open('predicted_images.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Citra', 'Kelas Aktual', 'Kelas Hasil Prediksi'])  # Write header row
    for i in range(total_images):
        writer.writerow([image_paths[i], actual_labels[i], predicted_labels[i]])

# %% [markdown]
# Muat file csv dan simpan isi file tersebut ke dalam docx

# %%
# Read the CSV file
csv_file = 'predicted_images.csv'
data = pd.read_csv(csv_file)

# Create a new Document
doc = Document()

# Create a table with 1 header row and 3 columns
table = doc.add_table(rows=1, cols=3)
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Citra'
hdr_cells[1].text = 'Kelas Aktual'
hdr_cells[2].text = 'Kelas Hasil Prediksi'

# Loop through each row in the DataFrame
for index, row in data.iterrows():
    # Create a new row for each image
    row_cells = table.add_row().cells

    # Add the image to the first cell
    img_path = row['Citra']
    if os.path.exists(img_path):  # Check if the image file exists
        paragraph = row_cells[0].add_paragraph()
        run = paragraph.add_run()
        run.add_picture(img_path, width=Inches(2))  # Adjust width as necessary
    else:
        row_cells[0].text = f"Tidak ada citra: {img_path}"

    # Add actual and predicted labels to the other cells
    row_cells[1].text = str(row['Kelas Aktual'])
    row_cells[2].text = str(row['Kelas Hasil Prediksi'])

# Save the document
doc.save('predicted_images.docx')

# %% [markdown]
# # **Confusion Matrix dan Matriks Pengujian**

# %% [markdown]
# Deklarasi confusion matrix dan tampilkan nilai TP, TN, FP, dan FN

# %%
cm = metrics.confusion_matrix(actual, predicted)

sns.heatmap(cm, annot=True, fmt="d", xticklabels=['Ergonomis', 'Tidak Ergonomis'], yticklabels=['Ergonomis', 'Tidak Ergonomis'])
plt.ylabel('Kelas Aktual')
plt.xlabel('Kelas Hasil Prediksi')
plt.show()

# %% [markdown]
# Hitung nilai matriks pengujian

# %%
TP = cm[0, 0]
FP = cm[0, 1]
TN = cm[1, 1]
FN = cm[1, 0]

accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# Tampilkan hasil matriks pengujian

# %%
print(f"Accuracy\t: {accuracy * 100:.2f}%")
print(f"Precision\t: {precision * 100:.2f}%")
print(f"Recall\t\t: {recall * 100:.2f}%")
print(f"F1 Score\t: {f1_score * 100:.2f}%")
# Out:
# Accuracy	: 95.06%
# Precision	: 98.77%
# Recall		: 91.95%
# F1 Score	: 95.24%
